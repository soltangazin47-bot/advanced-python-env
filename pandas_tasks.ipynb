# %%
# !python -m pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 3.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.9 MB 9.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 13.8 MB/s  0:00:01
# ...

# %%
import pandas as pd

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [19, 21, 22, 20, 23],
    "Score": [85, 78, 92, 88, 95]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 1      Bob   21     78
# 2  Charlie   22     92
# 3    David   20     88
# 4      Eva   23     95

# %%
df.head(3)
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 1      Bob   21     78
# 2  Charlie   22     92

# %%
df.describe()
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   21.000000  87.600000
# std     1.581139   6.580274
# min    19.000000  78.000000
# 25%    20.000000  85.000000
# 50%    21.000000  88.000000
# 75%    22.000000  92.000000
# max    23.000000  95.000000

# %%
df["Score"].mean()
# Out:
# np.float64(87.6)

# %%
df[df["Age"] > 20]
# Out:
#       Name  Age  Score
# 1      Bob   21     78
# 2  Charlie   22     92
# 4      Eva   23     95

# %%
df[df["Score"] > 80]
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 2  Charlie   22     92
# 3    David   20     88
# 4      Eva   23     95
